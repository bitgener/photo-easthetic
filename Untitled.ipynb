# %%
import keras
import random
import os
from keras import backend as K    
from keras.models import Sequential
from keras.layers.core import Flatten, Dense, Dropout
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D
from keras.optimizers import SGD
from sklearn.decomposition import PCA
from sklearn import svm
import numpy as np
from PIL import Image  

#规范化图像大小为96*96像素
def crop_and_scale_image(im):
    if im.mode is not 'RGB':
        im = im.convert('RGB')
    width,height = im.size
    if width > height:
        diff = width - height
        box = diff/2, 0, width - (diff - diff/2), height
    else:
        diff = height - width
        box = 0, diff/2, width, height - (diff - diff/2)
    im = im.crop(box)
    toSize = 96,96
    im= im.resize(toSize, Image.ANTIALIAS)
    return im

#从文件名解析标签进行分类
def fnames_to_labels(fnames):
    res = []
    for fname in fnames:
        score = float(fname.split('_')[1].split('.jpeg')[0])
        if score >5:
            res.append(1)
        else:
            res.append(-1)
    return np.asarray(res)

#加载数据库里所有图片，分为训练、验证和测试三类
dname = "E:/python-workspace/dataset/"
im_paths = [dname+fname for fname in os.listdir(dname) if fname.endswith(".jpeg")]
im_paths = np.array(im_paths)
random.shuffle(im_paths)
im_labels = fnames_to_labels(im_paths)

im_paths_pos = im_paths[im_labels>0]
im_paths_neg = im_paths[im_labels<0]
print (len(im_paths_pos),len(im_paths_neg))
fnames_te = np.concatenate((im_paths_pos[0:250], im_paths_neg[:250]))
fnames_va = np.concatenate((im_paths_pos[250:750], im_paths_neg[250:750]))
fnames_tr = np.concatenate((im_paths_pos[750:len(im_paths_neg)], im_paths_neg[750:]))
print ("Train data size: ",len(fnames_tr))
print ("Validation data size: ",len(fnames_va))
print ("Test data size: ",len(fnames_te))

#找到最佳svm参数
def svm_train(X, y, C, gamma):
    rbf_svc = svm.SVC(kernel='rbf', gamma=gamma, C=C).fit(X, y)
    return rbf_svc
    pass

def svm_predict(svc, X):
    return svc.predict(X)

K.set_image_dim_ordering('th')
C_range = np.logspace(-2, 7, 10)
gamma_range = np.logspace(-8, 1, 10)

best = 0
best_C = 0
best_gamma = 0
best_pca_n = 0

#VGG16预训练网络进行特征提取，使用展平图层的输出作为图像的提取特征。
def VGG_16(weights_path=None):
    model = Sequential()
    model.add(ZeroPadding2D((1,1),input_shape=(3,224,224)))
    model.add(Convolution2D(64, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(64, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(128, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(128, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(Flatten())
    model.add(Dense(4096, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(4096, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1000, activation='softmax'))

    if weights_path:
        model.load_weights(weights_path,by_name=True)
    
    new_model = Sequential()
    new_model.add(ZeroPadding2D((1,1),input_shape=(3,96,96)))
    new_model.add(Convolution2D(64, 3, 3, activation='relu'))
    new_model.add(ZeroPadding2D((1,1)))
    new_model.add(Convolution2D(64, 3, 3, activation='relu'))
    new_model.add(MaxPooling2D((2,2), strides=(2,2)))

    new_model.add(ZeroPadding2D((1,1)))
    new_model.add(Convolution2D(128, 3, 3, activation='relu'))
    new_model.add(ZeroPadding2D((1,1)))
    new_model.add(Convolution2D(128, 3, 3, activation='relu'))
    new_model.add(MaxPooling2D((2,2), strides=(2,2)))

    new_model.add(ZeroPadding2D((1,1)))
    new_model.add(Convolution2D(256, 3, 3, activation='relu'))
    new_model.add(ZeroPadding2D((1,1)))
    new_model.add(Convolution2D(256, 3, 3, activation='relu'))
    new_model.add(ZeroPadding2D((1,1)))
    new_model.add(Convolution2D(256, 3, 3, activation='relu'))
    new_model.add(MaxPooling2D((2,2), strides=(2,2)))

    new_model.add(ZeroPadding2D((1,1)))
    new_model.add(Convolution2D(512, 3, 3, activation='relu'))
    new_model.add(ZeroPadding2D((1,1)))
    new_model.add(Convolution2D(512, 3, 3, activation='relu'))
    new_model.add(ZeroPadding2D((1,1)))
    new_model.add(Convolution2D(512, 3, 3, activation='relu'))
    new_model.add(MaxPooling2D((2,2), strides=(2,2)))

    new_model.add(ZeroPadding2D((1,1)))
    new_model.add(Convolution2D(512, 3, 3, activation='relu'))
    new_model.add(ZeroPadding2D((1,1)))
    new_model.add(Convolution2D(512, 3, 3, activation='relu'))
    new_model.add(ZeroPadding2D((1,1)))
    new_model.add(Convolution2D(512, 3, 3, activation='relu'))
    new_model.add(MaxPooling2D((2,2), strides=(2,2)))

    new_model.add(Flatten())
    
    weights = model.get_weights()
    new_model.set_weights(weights)
    
    return new_model
    
trained_vgg = VGG_16("E:/python-workspace/vgg16_weights.h5")

#将预先训练的权重加载到VGG16网络后，我们现在可以将原始图像（3x 96 x 96）转换为来自展平层的特征向量（1 x 4608）
def get_Vgg16features(fnames, vgg):
    result = []
    for fname in fnames:
        im = Image.open(fname)
        im = crop_and_scale_image(im)
        if im.mode is not 'RGB':
            im = im.convert('RGB')
        npim = np.asarray(im)
        vgg_input = np.rollaxis(npim, 2)
        result.append(vgg_input)
        
    result_np = np.asarray(result)
    print (result_np.shape)
    return vgg.predict(result_np), fnames_to_labels(fnames)

X_tr, y_tr = get_Vgg16features(fnames_tr, trained_vgg)
X_va, y_va = get_Vgg16features(fnames_va, trained_vgg)
X_te, y_te = get_Vgg16features(fnames_te, trained_vgg)

#应用PCA提取主要组件作为新特征但具有较低维度，并且训练SVM分类器具有新特征。为了找到最佳参数，我们进行了验证并使用优化参数来处理测试集。
# validation
for pca_n in [1024,2048,3072,4096]:
    pca = PCA(n_components=pca_n)
    X_tr_pca = pca.fit_transform(X_tr)
    X_va_pca = pca.transform(X_va)
    for C in C_range:
        for gamma in gamma_range:
            svc = svm_train(X_tr_pca, y_tr, C, gamma)
            y_p = svm_predict(svc, X_va_pca)
            accuracy = np.mean(y_p==y_va)
            if accuracy > best:
                best = accuracy
                best_C = C
                best_gamma = gamma
                best_pca_n = pca_n
            recallT = 0.0
            recallF = 0.0
            for i in range(len(y_va)):
                if (y_p[i]==y_va[i] and y_p[i]>0):
                    recallT += 1
                if (y_p[i]==y_va[i] and y_p[i]<0):
                    recallF += 1
            print( "Validation PCA_N: {} C: {} gamma:{} accuracy: {} Recall: {},{}".format(pca_n,C,gamma,accuracy,recallT/(y_va>0).sum(),recallF/(y_va<=0).sum()))
# Out:
# E:\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# 4503 4544
# Train data size:  7547
# Validation data size:  1000
# Test data size:  500
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:78: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:80: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:84: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:86: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:90: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:92: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:94: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:98: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:100: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:102: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:110: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:125: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:127: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:131: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:133: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:137: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:139: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:141: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:145: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:147: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:149: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:153: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:155: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:157: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu")`
# (7547, 3, 96, 96)
# (1000, 3, 96, 96)
# (500, 3, 96, 96)
# Validation PCA_N: 1024 C: 0.01 gamma:1e-08 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 0.01 gamma:1e-07 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 0.01 gamma:1e-06 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 0.01 gamma:1e-05 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 0.01 gamma:0.0001 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 0.01 gamma:0.001 accuracy: 0.611 Recall: 0.34,0.882
# Validation PCA_N: 1024 C: 0.01 gamma:0.01 accuracy: 0.683 Recall: 0.688,0.678
# Validation PCA_N: 1024 C: 0.01 gamma:0.1 accuracy: 0.692 Recall: 0.712,0.672
# Validation PCA_N: 1024 C: 0.01 gamma:1.0 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 0.01 gamma:10.0 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 0.1 gamma:1e-08 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 0.1 gamma:1e-07 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 0.1 gamma:1e-06 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 0.1 gamma:1e-05 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 0.1 gamma:0.0001 accuracy: 0.629 Recall: 0.398,0.86
# Validation PCA_N: 1024 C: 0.1 gamma:0.001 accuracy: 0.685 Recall: 0.67,0.7
# Validation PCA_N: 1024 C: 0.1 gamma:0.01 accuracy: 0.703 Recall: 0.726,0.68
# Validation PCA_N: 1024 C: 0.1 gamma:0.1 accuracy: 0.727 Recall: 0.746,0.708
# Validation PCA_N: 1024 C: 0.1 gamma:1.0 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 0.1 gamma:10.0 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 1.0 gamma:1e-08 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 1.0 gamma:1e-07 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 1.0 gamma:1e-06 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 1.0 gamma:1e-05 accuracy: 0.63 Recall: 0.404,0.856
# Validation PCA_N: 1024 C: 1.0 gamma:0.0001 accuracy: 0.685 Recall: 0.664,0.706
# Validation PCA_N: 1024 C: 1.0 gamma:0.001 accuracy: 0.708 Recall: 0.726,0.69
# Validation PCA_N: 1024 C: 1.0 gamma:0.01 accuracy: 0.765 Recall: 0.784,0.746
# Validation PCA_N: 1024 C: 1.0 gamma:0.1 accuracy: 0.795 Recall: 0.798,0.792
# Validation PCA_N: 1024 C: 1.0 gamma:1.0 accuracy: 0.713 Recall: 0.62,0.806
# Validation PCA_N: 1024 C: 1.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0
# Validation PCA_N: 1024 C: 10.0 gamma:1e-08 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 10.0 gamma:1e-07 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 10.0 gamma:1e-06 accuracy: 0.629 Recall: 0.404,0.854
# Validation PCA_N: 1024 C: 10.0 gamma:1e-05 accuracy: 0.685 Recall: 0.664,0.706
# Validation PCA_N: 1024 C: 10.0 gamma:0.0001 accuracy: 0.708 Recall: 0.704,0.712
# Validation PCA_N: 1024 C: 10.0 gamma:0.001 accuracy: 0.763 Recall: 0.776,0.75
# Validation PCA_N: 1024 C: 10.0 gamma:0.01 accuracy: 0.794 Recall: 0.804,0.784
# Validation PCA_N: 1024 C: 10.0 gamma:0.1 accuracy: 0.79 Recall: 0.794,0.786
# Validation PCA_N: 1024 C: 10.0 gamma:1.0 accuracy: 0.724 Recall: 0.642,0.806
# Validation PCA_N: 1024 C: 10.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0
# Validation PCA_N: 1024 C: 100.0 gamma:1e-08 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 100.0 gamma:1e-07 accuracy: 0.629 Recall: 0.404,0.854
# Validation PCA_N:
C: 10000000.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0
# Validation PCA_N: 2048 C: 0.01 gamma:1e-08 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 0.01 gamma:1e-07 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 0.01 gamma:1e-06 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 0.01 gamma:1e-05 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 0.01 gamma:0.0001 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 0.01 gamma:0.001 accuracy: 0.612 Recall: 0.34,0.884
# Validation PCA_N: 2048 C: 0.01 gamma:0.01 accuracy: 0.684 Recall: 0.688,0.68
# Validation PCA_N: 2048 C: 0.01 gamma:0.1 accuracy: 0.691 Recall: 0.708,0.674
# Validation PCA_N: 2048 C: 0.01 gamma:1.0 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 0.01 gamma:10.0 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 0.1 gamma:1e-08 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 0.1 gamma:1e-07 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 0.1 gamma:1e-06 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 0.1 gamma:1e-05 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 0.1 gamma:0.0001 accuracy: 0.629 Recall: 0.398,0.86
# Validation PCA_N: 2048 C: 0.1 gamma:0.001 accuracy: 0.685 Recall: 0.67,0.7
# Validation PCA_N: 2048 C: 0.1 gamma:0.01 accuracy: 0.703 Recall: 0.726,0.68
# Validation PCA_N: 2048 C: 0.1 gamma:0.1 accuracy: 0.726 Recall: 0.744,0.708
# Validation PCA_N: 2048 C: 0.1 gamma:1.0 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 0.1 gamma:10.0 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 1.0 gamma:1e-08 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 1.0 gamma:1e-07 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 1.0 gamma:1e-06 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 1.0 gamma:1e-05 accuracy: 0.63 Recall: 0.404,0.856
# Validation PCA_N: 2048 C: 1.0 gamma:0.0001 accuracy: 0.685 Recall: 0.664,0.706
# Validation PCA_N: 2048 C: 1.0 gamma:0.001 accuracy: 0.708 Recall: 0.726,0.69
# Validation PCA_N: 2048 C: 1.0 gamma:0.01 accuracy: 0.764 Recall: 0.784,0.744
# Validation PCA_N: 2048 C: 1.0 gamma:0.1 accuracy: 0.794 Recall: 0.798,0.79
# Validation PCA_N: 2048 C: 1.0 gamma:1.0 accuracy: 0.702 Recall: 0.584,0.82
# Validation PCA_N: 2048 C: 1.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0
# Validation PCA_N: 2048 C: 10.0 gamma:1e-08 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 10.0 gamma:1e-07 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 10.0 gamma:1e-06 accuracy: 0.629 Recall: 0.404,0.854
# Validation PCA_N: 2048 C: 10.0 gamma:1e-05 accuracy: 0.685 Recall: 0.664,0.706
# Validation PCA_N: 2048 C: 10.0 gamma:0.0001 accuracy: 0.709 Recall: 0.706,0.712
# Validation PCA_N: 2048 C: 10.0 gamma:0.001 accuracy: 0.764 Recall: 0.782,0.746
# Validation PCA_N: 2048 C: 10.0 gamma:0.01 accuracy: 0.794 Recall: 0.796,0.792
# Validation PCA_N: 2048 C: 10.0 gamma:0.1 accuracy: 0.786 Recall: 0.786,0.786
# Validation PCA_N: 2048 C: 10.0 gamma:1.0 accuracy: 0.71 Recall: 0.606,0.814
# Validation PCA_N: 2048 C: 10.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0
# Validation PCA_N: 2048 C: 100.0 gamma:1e-08 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 100.0 gamma:1e-07 accuracy: 0.629 Recall: 0.404,0.854
# Validation PCA_N: 2048 C: 100.0 gamma:1e-06 accuracy: 0.685 Recall: 0.664,0.706
# Validation PCA_N: 2048 C: 100.0 gamma:1e-05 accuracy: 0.709 Recall: 0.704,0.714
# Validation PCA_N: 2048 C: 100.0 gamma:0.0001 accuracy: 0.761 Recall: 0.776,0.746
# Validation PCA_N: 2048 C: 100.0 gamma:0.001 accuracy: 0.788 Recall: 0.788,0.788
# Validation PCA_N: 2048 C: 100.0 gamma:0.01 accuracy: 0.775 Recall: 0.792,0.758
# Validation PCA_N: 2048 C: 100.0 gamma:0.1 accuracy: 0.784 Recall: 0.784,0.784
# Validation PCA_N: 2048 C: 100.0 gamma:1.0 accuracy: 0.71 Recall: 0.606,0.814
# Validation PCA_N: 2048 C: 100.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0
# Validation PCA_N: 2048 C: 1000.0 gamma:1e-08 accuracy: 0.629 Recall: 0.404,0.854
# Validation PCA_N: 2048 C: 1000.0 gamma:1e-07 accuracy: 0.685 Recall: 0.664,0.706
# Validation PCA_N: 2048 C: 1000.0 gamma:1e-06 accuracy: 0.708 Recall: 0.702,0.714
# Validation PCA_N: 2048 C: 1000.0 gamma:1e-05 accuracy: 0.763 Recall: 0.774,0.752
# Validation PCA_N: 2048 C: 1000.0 gamma:0.0001 accuracy: 0.783 Recall: 0.782,0.784
# Validation PCA_N: 2048 C: 1000.0 gamma:0.001 accuracy: 0.78 Recall: 0.786,0.774
# Validation PCA_N: 2048 C: 1000.0 gamma:0.01 accuracy: 0.736 Recall: 0.74,0.732
# Validation PCA_N: 2048 C: 1000.0 gamma:0.1 accuracy: 0.784 Recall: 0.784,0.784
# Validation PCA_N: 2048 C: 1000.0 gamma:1.0 accuracy: 0.71 Recall: 0.606,0.814
# Validation PCA_N: 2048 C: 1000.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0
# Validation PCA_N: 2048 C: 10000.0 gamma:1e-08 accuracy: 0.685 Recall: 0.664,0.706
# Validation PCA_N: 2048 C: 10000.0 gamma:1e-07 accuracy: 0.708 Recall: 0.702,0.714
# Validation PCA_N: 2048 C: 10000.0 gamma:1e-06 accuracy: 0.762 Recall: 0.774,0.75
# Validation PCA_N: 2048 C: 10000.0 gamma:1e-05 accuracy: 0.78 Recall: 0.782,0.778
# Validation PCA_N: 2048 C: 10000.0 gamma:0.0001 accuracy: 0.783 Recall: 0.772,0.794
# Validation PCA_N: 2048 C: 10000.0 gamma:0.001 accuracy: 0.742 Recall: 0.746,0.738
# Validation PCA_N: 2048 C: 10000.0 gamma:0.01 accuracy: 0.741 Recall: 0.744,0.738
# Validation PCA_N: 2048 C: 10000.0 gamma:0.1 accuracy: 0.784 Recall: 0.784,0.784
# Validation PCA_N: 2048 C: 10000.0 gamma:1.0 accuracy: 0.71 Recall: 0.606,0.814
# Validation PCA_N: 2048 C: 10000.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0
# Validation PCA_N: 2048 C: 100000.0 gamma:1e
0 gamma:1.0 accuracy: 0.7 Recall: 0.58,0.82
# Validation PCA_N: 4096 C: 1000.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0
# Validation PCA_N: 4096 C: 10000.0 gamma:1e-08 accuracy: 0.685 Recall: 0.664,0.706
# Validation PCA_N: 4096 C: 10000.0 gamma:1e-07 accuracy: 0.709 Recall: 0.704,0.714
# Validation PCA_N: 4096 C: 10000.0 gamma:1e-06 accuracy: 0.761 Recall: 0.77,0.752
# Validation PCA_N: 4096 C: 10000.0 gamma:1e-05 accuracy: 0.781 Recall: 0.782,0.78
# Validation PCA_N: 4096 C: 10000.0 gamma:0.0001 accuracy: 0.758 Recall: 0.746,0.77
# Validation PCA_N: 4096 C: 10000.0 gamma:0.001 accuracy: 0.716 Recall: 0.706,0.726
# Validation PCA_N: 4096 C: 10000.0 gamma:0.01 accuracy: 0.735 Recall: 0.738,0.732
# Validation PCA_N: 4096 C: 10000.0 gamma:0.1 accuracy: 0.791 Recall: 0.786,0.796
# Validation PCA_N: 4096 C: 10000.0 gamma:1.0 accuracy: 0.7 Recall: 0.58,0.82
# Validation PCA_N: 4096 C: 10000.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0
# Validation PCA_N: 4096 C: 100000.0 gamma:1e-08 accuracy: 0.703 Recall: 0.706,0.7
# Validation PCA_N: 4096 C: 100000.0 gamma:1e-07 accuracy: 0.761 Recall: 0.768,0.754
# Validation PCA_N: 4096 C: 100000.0 gamma:1e-06 accuracy: 0.785 Recall: 0.788,0.782
# Validation PCA_N: 4096 C: 100000.0 gamma:1e-05 accuracy: 0.764 Recall: 0.754,0.774
# Validation PCA_N: 4096 C: 100000.0 gamma:0.0001 accuracy: 0.709 Recall: 0.69,0.728
# Validation PCA_N: 4096 C: 100000.0 gamma:0.001 accuracy: 0.709 Recall: 0.694,0.724
# Validation PCA_N: 4096 C: 100000.0 gamma:0.01 accuracy: 0.735 Recall: 0.738,0.732
# Validation PCA_N: 4096 C: 100000.0 gamma:0.1 accuracy: 0.791 Recall: 0.786,0.796
# Validation PCA_N: 4096 C: 100000.0 gamma:1.0 accuracy: 0.7 Recall: 0.58,0.82
# Validation PCA_N: 4096 C: 100000.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0
# Validation PCA_N: 4096 C: 1000000.0 gamma:1e-08 accuracy: 0.749 Recall: 0.764,0.734
# Validation PCA_N: 4096 C: 1000000.0 gamma:1e-07 accuracy: 0.781 Recall: 0.786,0.776
# Validation PCA_N: 4096 C: 1000000.0 gamma:1e-06 accuracy: 0.773 Recall: 0.758,0.788
# Validation PCA_N: 4096 C: 1000000.0 gamma:1e-05 accuracy: 0.706 Recall: 0.71,0.702
# Validation PCA_N: 4096 C: 1000000.0 gamma:0.0001 accuracy: 0.698 Recall: 0.686,0.71
# Validation PCA_N: 4096 C: 1000000.0 gamma:0.001 accuracy: 0.709 Recall: 0.694,0.724
# Validation PCA_N: 4096 C: 1000000.0 gamma:0.01 accuracy: 0.735 Recall: 0.738,0.732
# Validation PCA_N: 4096 C: 1000000.0 gamma:0.1 accuracy: 0.791 Recall: 0.786,0.796
# Validation PCA_N: 4096 C: 1000000.0 gamma:1.0 accuracy: 0.7 Recall: 0.58,0.82
# Validation PCA_N: 4096 C: 1000000.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0
# Validation PCA_N: 4096 C: 10000000.0 gamma:1e-08 accuracy: 0.764 Recall: 0.776,0.752
# Validation PCA_N: 4096 C: 10000000.0 gamma:1e-07 accuracy: 0.791 Recall: 0.79,0.792
# Validation PCA_N: 4096 C: 10000000.0 gamma:1e-06 accuracy: 0.738 Recall: 0.73,0.746
# Validation PCA_N: 4096 C: 10000000.0 gamma:1e-05 accuracy: 0.703 Recall: 0.692,0.714
# Validation PCA_N: 4096 C: 10000000.0 gamma:0.0001 accuracy: 0.698 Recall: 0.686,0.71
# Validation PCA_N: 4096 C: 10000000.0 gamma:0.001 accuracy: 0.709 Recall: 0.694,0.724
# Validation PCA_N: 4096 C: 10000000.0 gamma:0.01 accuracy: 0.735 Recall: 0.738,0.732
# Validation PCA_N: 4096 C: 10000000.0 gamma:0.1 accuracy: 0.791 Recall: 0.786,0.796
# Validation PCA_N: 4096 C: 10000000.0 gamma:1.0 accuracy: 0.7 Recall: 0.58,0.82
# Validation PCA_N: 4096 C: 10000000.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0

# %%
# test
pca_n = 3072
C = 10.0
gamma = 0.01
pca = PCA(n_components=pca_n)
X_tr_pca = pca.fit_transform(X_tr)
X_te_pca = pca.transform(X_te)
svc = svm_train(X_tr_pca, y_tr, C, gamma)
y_pt = svm_predict(svc, X_te_pca)
print ("Test accuracy: {}".format(np.mean(y_pt==y_te)))
recallT = 0.0
recallF = 0.0
for i in range(len(y_te)):
    print("the %d  of photo's result is %s"%(i,y_pt[i]))
    if (y_pt[i]==y_te[i] and y_pt[i]>0):
        recallT += 1
    if (y_pt[i]==y_te[i] and y_pt[i]<0):
        recallF += 1
print ('Recall: ',recallT/(y_te>0).sum(),recallF/(y_te<=0).sum())
# Out:
# Test accuracy: 0.774
# the 0  of photo's result is 1
# the 1  of photo's result is -1
# the 2  of photo's result is 1
# the 3  of photo's result is -1
# the 4  of photo's result is 1
# the 5  of photo's result is 1
# the 6  of photo's result is 1
# the 7  of photo's result is 1
# the 8  of photo's result is 1
# the 9  of photo's result is 1
# the 10  of photo's result is 1
# the 11  of photo's result is -1
# the 12  of photo's result is 1
# the 13  of photo's result is 1
# the 14  of photo's result is 1
# the 15  of photo's result is 1
# the 16  of photo's result is 1
# the 17  of photo's result is 1
# the 18  of photo's result is 1
# the 19  of photo's result is 1
# the 20  of photo's result is 1
# the 21  of photo's result is 1
# the 22  of photo's result is 1
# the 23  of photo's result is 1
# the 24  of photo's result is 1
# the 25  of photo's result is 1
# the 26  of photo's result is 1
# the 27  of photo's result is -1
# the 28  of photo's result is -1
# the 29  of photo's result is 1
# the 30  of photo's result is -1
# the 31  of photo's result is 1
# the 32  of photo's result is 1
# the 33  of photo's result is 1
# the 34  of photo's result is -1
# the 35  of photo's result is -1
# the 36  of photo's result is 1
# the 37  of photo's result is 1
# the 38  of photo's result is 1
# the 39  of photo's result is 1
# the 40  of photo's result is -1
# the 41  of photo's result is 1
# the 42  of photo's result is 1
# the 43  of photo's result is 1
# the 44  of photo's result is 1
# the 45  of photo's result is 1
# the 46  of photo's result is -1
# the 47  of photo's result is -1
# the 48  of photo's result is -1
# the 49  of photo's result is 1
# the 50  of photo's result is 1
# the 51  of photo's result is 1
# the 52  of photo's result is 1
# the 53  of photo's result is -1
# the 54  of photo's result is 1
# the 55  of photo's result is 1
# the 56  of photo's result is -1
# the 57  of photo's result is 1
# the 58  of photo's result is 1
# the 59  of photo's result is 1
# the 60  of photo's result is 1
# the 61  of photo's result is -1
# the 62  of photo's result is 1
# the 63  of photo's result is 1
# the 64  of photo's result is 1
# the 65  of photo's result is 1
# the 66  of photo's result is 1
# the 67  of photo's result is 1
# the 68  of photo's result is 1
# the 69  of photo's result is 1
# the 70  of photo's result is 1
# the 71  of photo's result is 1
# the 72  of photo's result is 1
# the 73  of photo's result is 1
# the 74  of photo's result is -1
# the 75  of photo's result is 1
# the 76  of photo's result is 1
# the 77  of photo's result is 1
# the 78  of photo's result is 1
# the 79  of photo's result is -1
# the 80  of photo's result is 1
# the 81  of photo's result is 1
# the 82  of photo's result is 1
# the 83  of photo's result is 1
# the 84  of photo's result is 1
# the 85  of photo's result is 1
# the 86  of photo's result is 1
# the 87  of photo's result is -1
# the 88  of photo's result is -1
# the 89  of photo's result is -1
# the 90  of photo's result is 1
# the 91  of photo's result is 1
# the 92  of photo's result is 1
# the 93  of photo's result is 1
# the 94  of photo's result is 1
# the 95  of photo's result is 1
# the 96  of photo's result is 1
# the 97  of photo's result is 1
# the 98  of photo's result is 1
# the 99  of photo's result is 1
# the 100  of photo's result is 1
# the 101  of photo's result is 1
# the 102  of photo's result is 1
# the 103  of photo's result is 1
# the 104  of photo's result is -1
# the 105  of photo's result is 1
# the 106  of photo's result is 1
# the 107  of photo's result is 1
# the 108  of photo's result is 1
# the 109  of photo's result is 1
# the 110  of photo's result is 1
# the 111  of photo's result is 1
# the 112  of photo's result is 1
# the 113  of photo's result is 1
# the 114  of photo's result is 1
# the 115  of photo's result is -1
# the 116  of photo's result is 1
# the 117  of photo's result is -1
# the 118  of photo's result is -1
# the 119  of photo's result is 1
# the 120  of photo's result is -1
# the 121  of photo's result is 1
# the 122  of photo's result is -1
# the 123  of photo's result is 1
# the 124  of photo's result is 1
# the 125  of photo's result is -1
# the 126  of photo's result is -1
# the 127  of photo's result is 1
# the 128  of photo's result is 1
# the 129  of photo's result is -1
# the 130  of photo's result is 1
# the 131  of photo's result is 1
# the 132  of photo's result is 1
# the 133  of photo's result is 1
# the 134  of photo's result is 1
# the 135  of photo's result is 1
# the 136  of photo's result is 1
# the 137  of photo's result is 1
# the 138  of photo's result is 1
# the 139  of photo's result is -1
# the 140  of photo's result is 1
# the 141  of photo's result is 1
# the 142  of photo's result is -1
# the 143  of photo's result is 1
# the 144  of photo's result is 1
# the 145  of photo's result is 1
# the 146  of photo's result is 1
# the 147  of photo's result is 1
# the 148  of photo's result is 1
# the 149  of photo's result is 1
# the 150  of photo's result is 1
# the 151  of photo's result is -1
# the 152  of photo's result is 1
# the 153  of photo's result is -1
# the 154  of photo's result is 1
# the 155  of photo's result is 1
# the 156  of photo's result is 1
# the 157  of photo's result is 1
# the 158  of photo's result is -1
# the 159  of photo's result is 1
# the 160  of photo's result is 1
# the 161  of photo's result is 1
# the 162  of photo's result is 1
# the 163  of photo's result is -1
# the 164  of photo's result is 1
# the 165  of photo's result is 1
# the 166  of photo's result is 1
# the 167  of photo's result is 1
# the 168  of photo's result is 1
# the 169  of photo's result is 1
# the 170  of photo's result is 1
# the 171  of photo's result is -1
# the 172  of photo's result is 1
# the 173  of photo's result is -1
# the 174  of photo's result is 1
# the 175  of photo's result is 1
# the 176  of photo's result is 1
# the 177  of photo's result is 1
# the 178  of photo's result is 1
# the 179  of photo's result is 1
# the 180  of photo's result is -1
# the 181  of photo's result is 1
# the 182  of photo's result is 1
# the 183  of photo's result is 1
# the 184  of photo's result is 1
# the 185  of photo's result is 1
# the 186  of photo's result is 1
# the 187  of photo's result is 1
# the 188  of photo's result is 1
# the 189  of photo's result is 1
# the 190  of photo's result is 1
# the 191  of photo's result is 1
# the 192  of photo's result is 1
# the 193  of photo's result is -1
# the 194  of photo's result is 1
# the 195  of photo's result is 1
# the 196  of photo's result is 1
# the 197  of photo's result is 1
# the 198  of photo's result is 1
# the 199  of photo's result is 1
# the 200  of photo's result is 1
# the 201  of photo's result is 1
# the 202  of photo's result is 1
# the 203  of photo's result is 1
# the 204  of photo's result is 1
# the 205  of photo's result is 1
# the 206  of photo's result is -1
# the 207  of photo's result is -1
# the 208  of photo's result is -1
# the 209  of photo's result is -1
# the 210  of photo's result is 1
# the 211  of photo's result is 1
# the 212  of photo's result is 1
# the 213  of photo's result is 1
# the 214  of photo's result is 1
# the 215  of photo's result is 1
# the 216  of photo's result is 1
# the 217  of photo's result is 1
# the 218  of photo's result is 1
# the 219  of photo's result is 1
# the 220  of photo's result is 1
# the 221  of photo's result is 1
# the 222  of photo's result is 1
# the 223  of photo's result is 1
# the 224  of photo's result is 1
# the 225  of photo's result is 1
# the 226  of photo's result is 1
# the 227  of photo's result is -1
# the 228  of photo's result is 1
# the 229  of photo's result is 1
# the 230  of photo's result is 1
# the 231  of photo's result is -1
# the 232  of photo's result is -1
# the 233  of photo's result is 1
# the 234  of photo's result is 1
# the 235  of photo's result is 1
# the 236  of photo's result is -1
# the 237  of photo's result is 1
# the 238  of photo's result is 1
# the 239  of photo's result is 1
# the 240  of photo's result is 1
# the 241  of photo's result is 1
# the 242  of photo's result is 1
# the 243  of photo's result is 1
# the 244  of photo's result is 1
# the 245  of photo's result is 1
# the 246  of photo's result is -1
# the 247  of photo's result is 1
# the 248  of photo's result is 1
# the 249  of photo's result is 1
# the 250  of photo's result is -1
# the 251  of photo's result is -1
# the 252  of photo's result is -1
# the 253  of photo's result is 1
# the 254  of photo's result is 1
# the 255  of photo's result is -1
# the 256  of photo's result is -1
# the 257  of photo's result is -1
# the 258  of photo's result is -1
# the 259  of photo's result is -1
# the 260  of photo's result is -1
# the 261  of photo's result is -1
# the 262  of photo's result is -1
# the 263  of photo's result is -1
# the 264  of photo's result is 1
# the 265  of photo's result is -1
# the 266  of photo's result is 1
# the 267  of photo's result is -1
# the 268  of photo's result is 1
# the 269  of photo's result is -1
# the 270  of photo's result is -1
# the 271  of photo's result is -1
# the 272  of photo's result is -1
# the 273  of photo's result is -1
# the 274  of photo's result is 1
# the 275  of photo's result is -1
# the 276  of photo's result is 1
# the 277  of photo's result is -1
# the 278  of photo's result is 1
# the 279  of photo's result is -1
# the 280  of photo's result is -1
# the 281  of photo's result is -1
# the 282  of photo's result is -1
# the 283  of photo's result is 1
# the 284  of photo's result is -1
# the 285  of photo's result is -1
# the 286  of photo's result is -1
# the 287  of photo's result is -1
# the 288  of photo's result is -1
# the 289  of photo's result is -1
# the 290  of photo's result is -1
# the 291  of photo's result is -1
# the 292  of photo's result is -1
# the 293  of photo's result is -1
# the 294  of photo's result is -1
# the 295  of photo's result is 1
# the 296  of photo's result is -1
# the 297  of photo's result is -1
# the 298  of photo's result is -1
# the 299  of photo's result is 1
# the 300  of photo's result is -1
# the 301  of photo's result is 1
# the 302  of photo's result is -1
# the 303  of photo's result is -1
# the 304  of photo's result is -1
# the 305  of photo's result is -1
# the 306  of photo's result is 1
# the 307  of photo's result is -1
# the 308  of photo's result is -1
# the 309  of photo's result is -1
# the 310  of photo's result is -1
# the 311  of photo's result is -1
# the 312  of photo's result is -1
# the 313  of photo's result is -1
# the 314  of photo's result is -1
# the 315  of photo's result is -1
# the 316  of photo's result is -1
# the 317  of photo's result is -1
# the 318  of photo's result is 1
# the 319  of photo's result is -1
# the 320  of photo's result is -1
# the 321  of photo's result is 1
# the 322  of photo's result is 1
# the 323  of photo's result is -1
# the 324  of photo's result is -1
# the 325  of photo's result is -1
# the 326  of photo's result is -1
# the 327  of photo's result is 1
# the 328  of photo's result is 1
# the 329  of photo's result is 1
# the 330  of photo's result is -1
# the 331  of photo's result is -1
# the 332  of photo's result is -1
# the 333  of photo's result is -1
# the 334  of photo's result is -1
# the 335  of photo's result is -1
# the 336  of photo's result is -1
# the 337  of photo's result is 1
# the 338  of photo's result is -1
# the 339  of photo's result is -1
# the 340  of photo's result is -1
# the 341  of photo's result is 1
# the 342  of photo's result is 1
# the 343  of photo's result is -1
# the 344  of photo's result is -1
# the 345  of photo's result is -1
# the 346  of photo's result is -1
# the 347  of photo's result is -1
# the 348  of photo's result is 1
# the 349  of photo's result is -1
# the 350  of photo's result is -1
# the 351  of photo's result is 1
# the 352  of photo's result is 1
# the 353  of photo's result is -1
# the 354  of photo's result is -1
# the 355  of photo's result is -1
# the 356  of photo's result is 1
# the 357  of photo's result is 1
# the 358  of photo's result is 1
# the 359  of photo's result is -1
# the 360  of photo's result is -1
# the 361  of photo's result is -1
# the 362  of photo's result is -1
# the 363  of photo's result is -1
# the 364  of photo's result is -1
# the 365  of photo's result is 1
# the 366  of photo's result is -1
# the 367  of photo's result is -1
# the 368  of photo's result is 1
# the 369  of photo's result is -1
# the 370  of photo's result is -1
# the 371  of photo's result is -1
# the 372  of photo's result is -1
# the 373  of photo's result is -1
# the 374  of photo's result is -1
# the 375  of photo's result is -1
# the 376  of photo's result is -1
# the 377  of photo's result is 1
# the 378  of photo's result is 1
# the 379  of photo's result is -1
# the 380  of photo's result is -1
# the 381  of photo's result is 1
# the 382  of photo's result is 1
# the 383  of photo's result is 1
# the 384  of photo's result is -1
# the 385  of photo's result is -1
# the 386  of photo's result is -1
# the 387  of photo's result is -1
# the 388  of photo's result is 1
# the 389  of photo's result is -1
# the 390  of photo's result is -1
# the 391  of photo's result is -1
# the 392  of photo's result is 1
# the 393  of photo's result is -1
# the 394  of photo's result is 1
# the 395  of photo's result is 1
# the 396  of photo's result is -1
# the 397  of photo's result is 1
# the 398  of photo's result is 1
# the 399  of photo's result is -1
# the 400  of photo's result is 1
# the 401  of photo's result is 1
# the 402  of photo's result is 1
# the 403  of photo's result is -1
# the 404  of photo's result is -1
# the 405  of photo's result is -1
# the 406  of photo's result is 1
# the 407  of photo's result is -1
# the 408  of photo's result is -1
# the 409  of photo's result is -1
# the 410  of photo's result is 1
# the 411  of photo's result is -1
# the 412  of photo's result is -1
# the 413  of photo's result is -1
# the 414  of photo's result is -1
# the 415  of photo's result is -1
# the 416  of photo's result is -1
# the 417  of photo's result is 1
# the 418  of photo's result is -1
# the 419  of photo's result is -1
# the 420  of photo's result is -1
# the 421  of photo's result is 1
# the 422  of photo's result is -1
# the 423  of photo's result is -1
# the 424  of photo's result is -1
# the 425  of photo's result is -1
# the 426  of photo's result is 1
# the 427  of photo's result is -1
# the 428  of photo's result is -1
# the 429  of photo's result is -1
# the 430  of photo's result is -1
# the 431  of photo's result is 1
# the 432  of photo's result is -1
# the 433  of photo's result is -1
# the 434  of photo's result is 1
# the 435  of photo's result is -1
# the 436  of photo's result is 1
# the 437  of photo's result is -1
# the 438  of photo's result is 1
# the 439  of photo's result is 1
# the 440  of photo's result is -1
# the 441  of photo's result is 1
# the 442  of photo's result is -1
# the 443  of photo's result is -1
# the 444  of photo's result is -1
# the 445  of photo's result is -1
# the 446  of photo's result is -1
# the 447  of photo's result is -1
# the 448  of photo's result is -1
# the 449  of photo's result is -1
# the 450  of photo's result is -1
# the 451  of photo's result is -1
# the 452  of photo's result is -1
# the 453  of photo's result is -1
# the 454  of photo's result is -1
# the 455  of photo's result is -1
# the 456  of photo's result is -1
# the 457  of photo's result is -1
# the 458  of photo's result is -1
# the 459  of photo's result is -1
# the 460  of photo's result is 1
# the 461  of photo's result is -1
# the 462  of photo's result is 1
# the 463  of photo's result is -1
# the 464  of photo's result is -1
# the 465  of photo's result is 1
# the 466  of photo's result is -1
# the 467  of photo's result is -1
# the 468  of photo's result is 1
# the 469  of photo's result is -1
# the 470  of photo's result is -1
# the 471  of photo's result is -1
# the 472  of photo's result is 1
# the 473  of photo's result is -1
# the 474  of photo's result is -1
# the 475  of photo's result is 1
# the 476  of photo's result is -1
# the 477  of photo's result is -1
# the 478  of photo's result is -1
# the 479  of photo's result is -1
# the 480  of photo's result is 1
# the 481  of photo's result is -1
# the 482  of photo's result is -1
# the 483  of photo's result is -1
# the 484  of photo's result is -1
# the 485  of photo's result is -1
# the 486  of photo's result is -1
# the 487  of photo's result is -1
# the 488  of photo's result is -1
# the 489  of photo's result is -1
# the 490  of photo's result is -1
# the 491  of photo's result is -1
# the 492  of photo's result is 1
# the 493  of photo's result is -1
# the 494  of photo's result is -1
# the 495  of photo's result is -1
# the 496  of photo's result is 1
# the 497  of photo's result is -1
# the 498  of photo's result is 1
# the 499  of photo's result is -1
# Recall:  0.808 0.74

# %%
import tensorflow as tf
import sys

# 先实例化一个Saver()类
saver = tf.train.Saver()
init = (tf.global_variables_initializer(), tf.local_variables_initializer())

with tf.Session() as sess:
    sess.run(init) 
    # 存储训练好的variables
    save_path = saver.save(sess, "E:/python-workspace/model.ckpt")
    print ("Model saved in file: %s" % save_path)
# Out:
# Model saved in file: E:/python-workspace/model.ckpt

# %%
import tensorflow as tf

pca_n = 3072
C = 10.0
gamma = 0.01

with tf.Session() as sess:
    sess = tf.Session()
    saver = tf.train.Saver()
    saver.restore(sess, "E:/python-workspace/model.ckpt.meta")
    print("Model restored.")
# Out:
# E:\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-bbadef33ef9a> in <module>()
#       7 with tf.Session() as sess:
#       8     sess = tf.Session()
# ----> 9     saver = tf.train.Saver()
#      10     saver.restore(sess, "E:/python-workspace/model.ckpt.meta")
#      11     print("Model restored.")
#
# E:\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py in __init__(self, var_list, reshape, sharded, max_to_keep, keep_checkpoint_every_n_hours, name, restore_sequentially, saver_def, builder, defer_build, allow_empty, write_version, pad_step_number, save_relative_paths, filename)
#    1309           time.time() + self._keep_checkpoint_every_n_hours * 3600)
#    1310     elif not defer_build:
# -> 1311       self.build()
#    1312     if self.saver_def:
#    1313       self._check_saver_def()
#
# E:\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py in build(self)
#    1318     if context.executing_eagerly():
#    1319       raise RuntimeError("Use save/restore instead of build in eager mode.")
# -> 1320     self._build(self._filename, build_save=True, build_restore=True)
#    1321
#    1322   def _build_eager(self, checkpoint_path, build_save, build_restore):
#
# E:\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py in _build(self, checkpoint_path, build_save, build_restore)
#    1343           return
#    1344         else:
# -> 1345           raise ValueError("No variables to save")
#    1346       self._is_empty = False
#    1347
#
# ValueError: No variables to save
