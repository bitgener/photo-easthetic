# %%
import keras
import random
import os
from keras import backend as K    
from keras.models import Sequential
from keras.layers.core import Flatten, Dense, Dropout
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D
from keras.optimizers import SGD
from sklearn.decomposition import PCA
from sklearn import svm
import numpy as np
from PIL import Image  

def crop_and_scale_image(im):
    if im.mode is not 'RGB':
        im = im.convert('RGB')
    width,height = im.size
    if width > height:
        diff = width - height
        box = diff/2, 0, width - (diff - diff/2), height
    else:
        diff = height - width
        box = 0, diff/2, width, height - (diff - diff/2)
    im = im.crop(box)
    toSize = 96,96
    im= im.resize(toSize, Image.ANTIALIAS)
    return im

def fnames_to_labels(fnames):
    res = []
    for fname in fnames:
        score = float(fname.split('_')[1].split('.jpeg')[0])
        if score > 5:
            res.append(1)
        else:
            res.append(-1)
    return np.asarray(res)

def svm_train(X, y, C, gamma):
    rbf_svc = svm.SVC(kernel='rbf', gamma=gamma, C=C).fit(X, y)
    return rbf_svc
    pass

def svm_predict(svc, X):
    return svc.predict(X)

K.set_image_dim_ordering('th')
C_range = np.logspace(-2, 7, 10)
gamma_range = np.logspace(-8, 1, 10)

best = 0
best_C = 0
best_gamma = 0
best_pca_n = 0

dname = "E:/python-workspace/dataset/"
im_paths = [dname+fname for fname in os.listdir(dname) if fname.endswith(".jpeg")]
im_paths = np.array(im_paths)
random.shuffle(im_paths)
im_labels = fnames_to_labels(im_paths)

im_paths_pos = im_paths[im_labels>0]
im_paths_neg = im_paths[im_labels<0]
print (len(im_paths_pos),len(im_paths_neg))
fnames_te = np.concatenate((im_paths_pos[0:250], im_paths_neg[:250]))
fnames_va = np.concatenate((im_paths_pos[250:750], im_paths_neg[250:750]))
fnames_tr = np.concatenate((im_paths_pos[750:len(im_paths_neg)], im_paths_neg[750:]))
print ("Train data size: ",len(fnames_tr))
print ("Validation data size: ",len(fnames_va))
print ("Test data size: ",len(fnames_te))

def VGG_16(weights_path=None):
    model = Sequential()
    model.add(ZeroPadding2D((1,1),input_shape=(3,224,224)))
    model.add(Convolution2D(64, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(64, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(128, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(128, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(Flatten())
    model.add(Dense(4096, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(4096, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1000, activation='softmax'))

    if weights_path:
        model.load_weights(weights_path,by_name=True)
    
    new_model = Sequential()
    new_model.add(ZeroPadding2D((1,1),input_shape=(3,96,96)))
    new_model.add(Convolution2D(64, 3, 3, activation='relu'))
    new_model.add(ZeroPadding2D((1,1)))
    new_model.add(Convolution2D(64, 3, 3, activation='relu'))
    new_model.add(MaxPooling2D((2,2), strides=(2,2)))

    new_model.add(ZeroPadding2D((1,1)))
    new_model.add(Convolution2D(128, 3, 3, activation='relu'))
    new_model.add(ZeroPadding2D((1,1)))
    new_model.add(Convolution2D(128, 3, 3, activation='relu'))
    new_model.add(MaxPooling2D((2,2), strides=(2,2)))

    new_model.add(ZeroPadding2D((1,1)))
    new_model.add(Convolution2D(256, 3, 3, activation='relu'))
    new_model.add(ZeroPadding2D((1,1)))
    new_model.add(Convolution2D(256, 3, 3, activation='relu'))
    new_model.add(ZeroPadding2D((1,1)))
    new_model.add(Convolution2D(256, 3, 3, activation='relu'))
    new_model.add(MaxPooling2D((2,2), strides=(2,2)))

    new_model.add(ZeroPadding2D((1,1)))
    new_model.add(Convolution2D(512, 3, 3, activation='relu'))
    new_model.add(ZeroPadding2D((1,1)))
    new_model.add(Convolution2D(512, 3, 3, activation='relu'))
    new_model.add(ZeroPadding2D((1,1)))
    new_model.add(Convolution2D(512, 3, 3, activation='relu'))
    new_model.add(MaxPooling2D((2,2), strides=(2,2)))

    new_model.add(ZeroPadding2D((1,1)))
    new_model.add(Convolution2D(512, 3, 3, activation='relu'))
    new_model.add(ZeroPadding2D((1,1)))
    new_model.add(Convolution2D(512, 3, 3, activation='relu'))
    new_model.add(ZeroPadding2D((1,1)))
    new_model.add(Convolution2D(512, 3, 3, activation='relu'))
    new_model.add(MaxPooling2D((2,2), strides=(2,2)))

    new_model.add(Flatten())
    
    weights = model.get_weights()
    new_model.set_weights(weights)
    
    return new_model
    
trained_vgg = VGG_16("E:/python-workspace/vgg16_weights.h5")

def get_Vgg16features(fnames, vgg):
    result = []
    for fname in fnames:
        im = Image.open(fname)
        im = crop_and_scale_image(im)
        if im.mode is not 'RGB':
            im = im.convert('RGB')
        npim = np.asarray(im)
        vgg_input = np.rollaxis(npim, 2)
        result.append(vgg_input)
        
    result_np = np.asarray(result)
    print (result_np.shape)
    return vgg.predict(result_np), fnames_to_labels(fnames)

X_tr, y_tr = get_Vgg16features(fnames_tr, trained_vgg)
X_va, y_va = get_Vgg16features(fnames_va, trained_vgg)
X_te, y_te = get_Vgg16features(fnames_te, trained_vgg)

# validation
for pca_n in [1024,2048,3072,4096]:
    pca = PCA(n_components=pca_n)
    X_tr_pca = pca.fit_transform(X_tr)
    X_va_pca = pca.transform(X_va)
    for C in C_range:
        for gamma in gamma_range:
            svc = svm_train(X_tr_pca, y_tr, C, gamma)
            y_p = svm_predict(svc, X_va_pca)
            accuracy = np.mean(y_p==y_va)
            if accuracy > best:
                best = accuracy
                best_C = C
                best_gamma = gamma
                best_pca_n = pca_n
            recallT = 0.0
            recallF = 0.0
            for i in range(len(y_va)):
                if (y_p[i]==y_va[i] and y_p[i]>0):
                    recallT += 1
                if (y_p[i]==y_va[i] and y_p[i]<0):
                    recallF += 1
            print( "Validation PCA_N: {} C: {} gamma:{} accuracy: {} Recall: {},{}".format(pca_n,C,gamma,accuracy,recallT/(y_va>0).sum(),recallF/(y_va<=0).sum()))
# Out:
# E:\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# 4503 4544
# Train data size:  7547
# Validation data size:  1000
# Test data size:  500
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:75: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:77: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:81: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:83: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:87: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:89: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:91: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:95: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:97: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:99: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:103: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:122: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:124: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:128: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:130: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:134: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:136: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:138: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:142: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:144: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:146: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:150: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:152: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu")`
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:154: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu")`
# (7547, 3, 96, 96)
# (1000, 3, 96, 96)
# (500, 3, 96, 96)
# Validation PCA_N: 1024 C: 0.01 gamma:1e-08 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 0.01 gamma:1e-07 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 0.01 gamma:1e-06 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 0.01 gamma:1e-05 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 0.01 gamma:0.0001 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 0.01 gamma:0.001 accuracy: 0.673 Recall: 0.62,0.726
# Validation PCA_N: 1024 C: 0.01 gamma:0.01 accuracy: 0.681 Recall: 0.65,0.712
# Validation PCA_N: 1024 C: 0.01 gamma:0.1 accuracy: 0.59 Recall: 0.248,0.932
# Validation PCA_N: 1024 C: 0.01 gamma:1.0 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 0.01 gamma:10.0 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 0.1 gamma:1e-08 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 0.1 gamma:1e-07 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 0.1 gamma:1e-06 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 0.1 gamma:1e-05 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 0.1 gamma:0.0001 accuracy: 0.678 Recall: 0.62,0.736
# Validation PCA_N: 1024 C: 0.1 gamma:0.001 accuracy: 0.686 Recall: 0.674,0.698
# Validation PCA_N: 1024 C: 0.1 gamma:0.01 accuracy: 0.718 Recall: 0.708,0.728
# Validation PCA_N: 1024 C: 0.1 gamma:0.1 accuracy: 0.675 Recall: 0.576,0.774
# Validation PCA_N: 1024 C: 0.1 gamma:1.0 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 0.1 gamma:10.0 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 1.0 gamma:1e-08 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 1.0 gamma:1e-07 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 1.0 gamma:1e-06 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 1.0 gamma:1e-05 accuracy: 0.679 Recall: 0.622,0.736
# Validation PCA_N: 1024 C: 1.0 gamma:0.0001 accuracy: 0.682 Recall: 0.648,0.716
# Validation PCA_N: 1024 C: 1.0 gamma:0.001 accuracy: 0.731 Recall: 0.74,0.722
# Validation PCA_N: 1024 C: 1.0 gamma:0.01 accuracy: 0.76 Recall: 0.762,0.758
# Validation PCA_N: 1024 C: 1.0 gamma:0.1 accuracy: 0.747 Recall: 0.732,0.762
# Validation PCA_N: 1024 C: 1.0 gamma:1.0 accuracy: 0.51 Recall: 0.024,0.996
# Validation PCA_N: 1024 C: 1.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0
# Validation PCA_N: 1024 C: 10.0 gamma:1e-08 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 10.0 gamma:1e-07 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 10.0 gamma:1e-06 accuracy: 0.679 Recall: 0.622,0.736
# Validation PCA_N: 1024 C: 10.0 gamma:1e-05 accuracy: 0.682 Recall: 0.648,0.716
# Validation PCA_N: 1024 C: 10.0 gamma:0.0001 accuracy: 0.738 Recall: 0.76,0.716
# Validation PCA_N: 1024 C: 10.0 gamma:0.001 accuracy: 0.763 Recall: 0.766,0.76
# Validation PCA_N: 1024 C: 10.0 gamma:0.01 accuracy: 0.78 Recall: 0.79,0.77
# Validation PCA_N: 1024 C: 10.0 gamma:0.1 accuracy: 0.753 Recall: 0.746,0.76
# Validation PCA_N: 1024 C: 10.0 gamma:1.0 accuracy: 0.519 Recall: 0.044,0.994
# Validation PCA_N: 1024 C: 10.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0
# Validation PCA_N: 1024 C: 100.0 gamma:1e-08 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 1024 C: 100.0 gamma:1e-07 accuracy: 0.679 Recall: 0.622,0.736
# Validation PCA_N: 1024 C: 100.0 gamma:1e-06 accuracy: 0.682 Recall: 0.648,0.716
# Validation PCA_N:
# Validation PCA_N: 1024 C: 10000000.0 gamma:0.001 accuracy: 0.73 Recall: 0.734,0.726
# Validation PCA_N: 1024 C: 10000000.0 gamma:0.01 accuracy: 0.737 Recall: 0.736,0.738
# Validation PCA_N: 1024 C: 10000000.0 gamma:0.1 accuracy: 0.752 Recall: 0.746,0.758
# Validation PCA_N: 1024 C: 10000000.0 gamma:1.0 accuracy: 0.519 Recall: 0.044,0.994
# Validation PCA_N: 1024 C: 10000000.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0
# Validation PCA_N: 2048 C: 0.01 gamma:1e-08 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 0.01 gamma:1e-07 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 0.01 gamma:1e-06 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 0.01 gamma:1e-05 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 0.01 gamma:0.0001 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 0.01 gamma:0.001 accuracy: 0.672 Recall: 0.618,0.726
# Validation PCA_N: 2048 C: 0.01 gamma:0.01 accuracy: 0.681 Recall: 0.65,0.712
# Validation PCA_N: 2048 C: 0.01 gamma:0.1 accuracy: 0.551 Recall: 0.13,0.972
# Validation PCA_N: 2048 C: 0.01 gamma:1.0 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 0.01 gamma:10.0 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 0.1 gamma:1e-08 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 0.1 gamma:1e-07 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 0.1 gamma:1e-06 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 0.1 gamma:1e-05 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 0.1 gamma:0.0001 accuracy: 0.678 Recall: 0.62,0.736
# Validation PCA_N: 2048 C: 0.1 gamma:0.001 accuracy: 0.685 Recall: 0.672,0.698
# Validation PCA_N: 2048 C: 0.1 gamma:0.01 accuracy: 0.718 Recall: 0.708,0.728
# Validation PCA_N: 2048 C: 0.1 gamma:0.1 accuracy: 0.667 Recall: 0.55,0.784
# Validation PCA_N: 2048 C: 0.1 gamma:1.0 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 0.1 gamma:10.0 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 1.0 gamma:1e-08 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 1.0 gamma:1e-07 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 1.0 gamma:1e-06 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 1.0 gamma:1e-05 accuracy: 0.679 Recall: 0.622,0.736
# Validation PCA_N: 2048 C: 1.0 gamma:0.0001 accuracy: 0.682 Recall: 0.648,0.716
# Validation PCA_N: 2048 C: 1.0 gamma:0.001 accuracy: 0.732 Recall: 0.742,0.722
# Validation PCA_N: 2048 C: 1.0 gamma:0.01 accuracy: 0.76 Recall: 0.764,0.756
# Validation PCA_N: 2048 C: 1.0 gamma:0.1 accuracy: 0.747 Recall: 0.728,0.766
# Validation PCA_N: 2048 C: 1.0 gamma:1.0 accuracy: 0.504 Recall: 0.012,0.996
# Validation PCA_N: 2048 C: 1.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0
# Validation PCA_N: 2048 C: 10.0 gamma:1e-08 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 10.0 gamma:1e-07 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 10.0 gamma:1e-06 accuracy: 0.679 Recall: 0.622,0.736
# Validation PCA_N: 2048 C: 10.0 gamma:1e-05 accuracy: 0.682 Recall: 0.648,0.716
# Validation PCA_N: 2048 C: 10.0 gamma:0.0001 accuracy: 0.736 Recall: 0.758,0.714
# Validation PCA_N: 2048 C: 10.0 gamma:0.001 accuracy: 0.769 Recall: 0.772,0.766
# Validation PCA_N: 2048 C: 10.0 gamma:0.01 accuracy: 0.775 Recall: 0.794,0.756
# Validation PCA_N: 2048 C: 10.0 gamma:0.1 accuracy: 0.755 Recall: 0.74,0.77
# Validation PCA_N: 2048 C: 10.0 gamma:1.0 accuracy: 0.509 Recall: 0.022,0.996
# Validation PCA_N: 2048 C: 10.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0
# Validation PCA_N: 2048 C: 100.0 gamma:1e-08 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 2048 C: 100.0 gamma:1e-07 accuracy: 0.679 Recall: 0.622,0.736
# Validation PCA_N: 2048 C: 100.0 gamma:1e-06 accuracy: 0.682 Recall: 0.648,0.716
# Validation PCA_N: 2048 C: 100.0 gamma:1e-05 accuracy: 0.737 Recall: 0.754,0.72
# Validation PCA_N: 2048 C: 100.0 gamma:0.0001 accuracy: 0.766 Recall: 0.774,0.758
# Validation PCA_N: 2048 C: 100.0 gamma:0.001 accuracy: 0.764 Recall: 0.788,0.74
# Validation PCA_N: 2048 C: 100.0 gamma:0.01 accuracy: 0.76 Recall: 0.782,0.738
# Validation PCA_N: 2048 C: 100.0 gamma:0.1 accuracy: 0.755 Recall: 0.74,0.77
# Validation PCA_N: 2048 C: 100.0 gamma:1.0 accuracy: 0.509 Recall: 0.022,0.996
# Validation PCA_N: 2048 C: 100.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0
# Validation PCA_N: 2048 C: 1000.0 gamma:1e-08 accuracy: 0.678 Recall: 0.62,0.736
# Validation PCA_N: 2048 C: 1000.0 gamma:1e-07 accuracy: 0.682 Recall: 0.648,0.716
# Validation PCA_N: 2048 C: 1000.0 gamma:1e-06 accuracy: 0.737 Recall: 0.75,0.724
# Validation PCA_N: 2048 C: 1000.0 gamma:1e-05 accuracy: 0.768 Recall: 0.774,0.762
# Validation PCA_N: 2048 C: 1000.0 gamma:0.0001 accuracy: 0.769 Recall: 0.778,0.76
# Validation PCA_N: 2048 C: 1000.0 gamma:0.001 accuracy: 0.738 Recall: 0.754,0.722
# Validation PCA_N: 2048 C: 1000.0 gamma:0.01 accuracy: 0.754 Recall: 0.782,0.726
# Validation PCA_N: 2048 C: 1000.0 gamma:0.1 accuracy: 0.755 Recall: 0.74,0.77
# Validation PCA_N: 2048 C: 1000.0 gamma:1.0 accuracy: 0.509 Recall: 0.022,0.996
# Validation PCA_N: 2048 C: 1000.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0
# Validation PCA_N: 2048 C: 10000.0 gamma:1e-08 accuracy: 0.682 Recall: 0.648,0.716
# Validation PCA_N: 2048 C: 10000.0 gamma:1e-07 accuracy: 0.738 Recall: 0.752,0.724
# Validation PCA_N: 2048 C: 10000.0 gamma:1e
accuracy: 0.682 Recall: 0.648,0.716
# Validation PCA_N: 3072 C: 1.0 gamma:0.001 accuracy: 0.732 Recall: 0.742,0.722
# Validation PCA_N: 3072 C: 1.0 gamma:0.01 accuracy: 0.759 Recall: 0.762,0.756
# Validation PCA_N: 3072 C: 1.0 gamma:0.1 accuracy: 0.746 Recall: 0.72,0.772
# Validation PCA_N: 3072 C: 1.0 gamma:1.0 accuracy: 0.504 Recall: 0.008,1.0
# Validation PCA_N: 3072 C: 1.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0
# Validation PCA_N: 3072 C: 10.0 gamma:1e-08 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 3072 C: 10.0 gamma:1e-07 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 3072 C: 10.0 gamma:1e-06 accuracy: 0.679 Recall: 0.622,0.736
# Validation PCA_N: 3072 C: 10.0 gamma:1e-05 accuracy: 0.682 Recall: 0.648,0.716
# Validation PCA_N: 3072 C: 10.0 gamma:0.0001 accuracy: 0.737 Recall: 0.758,0.716
# Validation PCA_N: 3072 C: 10.0 gamma:0.001 accuracy: 0.768 Recall: 0.77,0.766
# Validation PCA_N: 3072 C: 10.0 gamma:0.01 accuracy: 0.77 Recall: 0.784,0.756
# Validation PCA_N: 3072 C: 10.0 gamma:0.1 accuracy: 0.752 Recall: 0.73,0.774
# Validation PCA_N: 3072 C: 10.0 gamma:1.0 accuracy: 0.506 Recall: 0.016,0.996
# Validation PCA_N: 3072 C: 10.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0
# Validation PCA_N: 3072 C: 100.0 gamma:1e-08 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 3072 C: 100.0 gamma:1e-07 accuracy: 0.679 Recall: 0.622,0.736
# Validation PCA_N: 3072 C: 100.0 gamma:1e-06 accuracy: 0.682 Recall: 0.648,0.716
# Validation PCA_N: 3072 C: 100.0 gamma:1e-05 accuracy: 0.737 Recall: 0.754,0.72
# Validation PCA_N: 3072 C: 100.0 gamma:0.0001 accuracy: 0.768 Recall: 0.772,0.764
# Validation PCA_N: 3072 C: 100.0 gamma:0.001 accuracy: 0.761 Recall: 0.78,0.742
# Validation PCA_N: 3072 C: 100.0 gamma:0.01 accuracy: 0.751 Recall: 0.76,0.742
# Validation PCA_N: 3072 C: 100.0 gamma:0.1 accuracy: 0.752 Recall: 0.73,0.774
# Validation PCA_N: 3072 C: 100.0 gamma:1.0 accuracy: 0.506 Recall: 0.016,0.996
# Validation PCA_N: 3072 C: 100.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0
# Validation PCA_N: 3072 C: 1000.0 gamma:1e-08 accuracy: 0.678 Recall: 0.62,0.736
# Validation PCA_N: 3072 C: 1000.0 gamma:1e-07 accuracy: 0.682 Recall: 0.648,0.716
# Validation PCA_N: 3072 C: 1000.0 gamma:1e-06 accuracy: 0.736 Recall: 0.75,0.722
# Validation PCA_N: 3072 C: 1000.0 gamma:1e-05 accuracy: 0.766 Recall: 0.776,0.756
# Validation PCA_N: 3072 C: 1000.0 gamma:0.0001 accuracy: 0.766 Recall: 0.782,0.75
# Validation PCA_N: 3072 C: 1000.0 gamma:0.001 accuracy: 0.708 Recall: 0.718,0.698
# Validation PCA_N: 3072 C: 1000.0 gamma:0.01 accuracy: 0.743 Recall: 0.756,0.73
# Validation PCA_N: 3072 C: 1000.0 gamma:0.1 accuracy: 0.752 Recall: 0.73,0.774
# Validation PCA_N: 3072 C: 1000.0 gamma:1.0 accuracy: 0.506 Recall: 0.016,0.996
# Validation PCA_N: 3072 C: 1000.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0
# Validation PCA_N: 3072 C: 10000.0 gamma:1e-08 accuracy: 0.682 Recall: 0.648,0.716
# Validation PCA_N: 3072 C: 10000.0 gamma:1e-07 accuracy: 0.737 Recall: 0.754,0.72
# Validation PCA_N: 3072 C: 10000.0 gamma:1e-06 accuracy: 0.763 Recall: 0.774,0.752
# Validation PCA_N: 3072 C: 10000.0 gamma:1e-05 accuracy: 0.759 Recall: 0.78,0.738
# Validation PCA_N: 3072 C: 10000.0 gamma:0.0001 accuracy: 0.72 Recall: 0.728,0.712
# Validation PCA_N: 3072 C: 10000.0 gamma:0.001 accuracy: 0.707 Recall: 0.724,0.69
# Validation PCA_N: 3072 C: 10000.0 gamma:0.01 accuracy: 0.743 Recall: 0.756,0.73
# Validation PCA_N: 3072 C: 10000.0 gamma:0.1 accuracy: 0.752 Recall: 0.73,0.774
# Validation PCA_N: 3072 C: 10000.0 gamma:1.0 accuracy: 0.506 Recall: 0.016,0.996
# Validation PCA_N: 3072 C: 10000.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0
# Validation PCA_N: 3072 C: 100000.0 gamma:1e-08 accuracy: 0.735 Recall: 0.742,0.728
# Validation PCA_N: 3072 C: 100000.0 gamma:1e-07 accuracy: 0.76 Recall: 0.768,0.752
# Validation PCA_N: 3072 C: 100000.0 gamma:1e-06 accuracy: 0.763 Recall: 0.784,0.742
# Validation PCA_N: 3072 C: 100000.0 gamma:1e-05 accuracy: 0.714 Recall: 0.724,0.704
# Validation PCA_N: 3072 C: 100000.0 gamma:0.0001 accuracy: 0.7 Recall: 0.72,0.68
# Validation PCA_N: 3072 C: 100000.0 gamma:0.001 accuracy: 0.707 Recall: 0.724,0.69
# Validation PCA_N: 3072 C: 100000.0 gamma:0.01 accuracy: 0.743 Recall: 0.756,0.73
# Validation PCA_N: 3072 C: 100000.0 gamma:0.1 accuracy: 0.752 Recall: 0.73,0.774
# Validation PCA_N: 3072 C: 100000.0 gamma:1.0 accuracy: 0.506 Recall: 0.016,0.996
# Validation PCA_N: 3072 C: 100000.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0
# Validation PCA_N: 3072 C: 1000000.0 gamma:1e-08 accuracy: 0.748 Recall: 0.758,0.738
# Validation PCA_N: 3072 C: 1000000.0 gamma:1e-07 accuracy: 0.752 Recall: 0.786,0.718
# Validation PCA_N: 3072 C: 1000000.0 gamma:1e-06 accuracy: 0.711 Recall: 0.718,0.704
# Validation PCA_N: 3072 C: 1000000.0 gamma:1e-05 accuracy: 0.695 Recall: 0.716,0.674
# Validation PCA_N: 3072 C: 1000000.0 gamma:0.0001 accuracy: 0.689 Recall: 0.7,0.678
# Validation PCA_N: 3072 C: 1000000.0 gamma:0.001 accuracy: 0.707 Recall: 0.724,0.69
# Validation PCA_N: 3072 C: 1000000.0 gamma:0.01 accuracy: 0.743 Recall: 0.756,0.73
# Validation PCA_N: 3072 C: 1000000.0 gamma:0.1 accuracy: 0.752 Recall: 0.73,0.774
# Validation PCA_N: 3072 C: 1000000.0 gamma:1.0 accuracy: 0.506 Recall: 0.016,0.996
# Validation PCA_N: 3072 C: 1000000.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0
# Validation PCA_N: 3072 C: 10000000.0 gamma:1e-08 accuracy: 0.754 Recall: 0.774,0.734
# Validation PCA_N: 3072 C: 10000000.0 gamma:1e-07 accuracy: 0.75 Recall: 0.786,0.714
# Validation PCA_N: 3072 C: 10000000.0 gamma:1e-06 accuracy: 0.675 Recall: 0.696,0.654
# Validation PCA_N: 3072 C: 10000000.0 gamma:1e-05 accuracy: 0.678 Recall: 0.7,0.656
# Validation PCA_N: 3072 C: 10000000.0 gamma:0.0001 accuracy: 0.689 Recall: 0.7,0.678
# Validation PCA_N: 3072 C: 10000000.0 gamma:0.001 accuracy: 0.707 Recall: 0.724,0.69
# Validation PCA_N: 3072 C: 10000000.0 gamma:0.01 accuracy: 0.743 Recall: 0.756,0.73
# Validation PCA_N: 3072 C: 10000000.0 gamma:0.1 accuracy: 0.752 Recall: 0.73,0.774
# Validation PCA_N: 3072 C: 10000000.0 gamma:1.0 accuracy: 0.506 Recall: 0.016,0.996
# Validation PCA_N: 3072 C: 10000000.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0
# Validation PCA_N: 4096 C: 0.01 gamma:1e-08 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 4096 C: 0.01 gamma:1e-07 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 4096 C: 0.01 gamma:1e-06 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 4096 C: 0.01 gamma:1e-05 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 4096 C: 0.01 gamma:0.0001 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 4096 C: 0.01 gamma:0.001 accuracy: 0.673 Recall: 0.618,0.728
# Validation PCA_N: 4096 C: 0.01 gamma:0.01 accuracy: 0.681 Recall: 0.65,0.712
# Validation PCA_N: 4096 C: 0.01 gamma:0.1 accuracy: 0.533 Recall: 0.078,0.988
# Validation PCA_N: 4096 C: 0.01 gamma:1.0 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 4096 C: 0.01 gamma:10.0 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 4096 C: 0.1 gamma:1e-08 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 4096 C: 0.1 gamma:1e-07 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 4096 C: 0.1 gamma:1e-06 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 4096 C: 0.1 gamma:1e-05 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 4096 C: 0.1 gamma:0.0001 accuracy: 0.678 Recall: 0.62,0.736
# Validation PCA_N: 4096 C: 0.1 gamma:0.001 accuracy: 0.685 Recall: 0.672,0.698
# Validation PCA_N: 4096 C: 0.1 gamma:0.01 accuracy: 0.718 Recall: 0.708,0.728
# Validation PCA_N: 4096 C: 0.1 gamma:0.1 accuracy: 0.661 Recall: 0.534,0.788
# Validation PCA_N: 4096 C: 0.1 gamma:1.0 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 4096 C: 0.1 gamma:10.0 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 4096 C: 1.0 gamma:1e-08 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 4096 C: 1.0 gamma:1e-07 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 4096 C: 1.0 gamma:1e-06 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 4096 C: 1.0 gamma:1e-05 accuracy: 0.679 Recall: 0.622,0.736
# Validation PCA_N: 4096 C: 1.0 gamma:0.0001 accuracy: 0.682 Recall: 0.648,0.716
# Validation PCA_N: 4096 C: 1.0 gamma:0.001 accuracy: 0.733 Recall: 0.742,0.724
# Validation PCA_N: 4096 C: 1.0 gamma:0.01 accuracy: 0.759 Recall: 0.762,0.756
# Validation PCA_N: 4096 C: 1.0 gamma:0.1 accuracy: 0.745 Recall: 0.714,0.776
# Validation PCA_N: 4096 C: 1.0 gamma:1.0 accuracy: 0.504 Recall: 0.008,1.0
# Validation PCA_N: 4096 C: 1.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0
# Validation PCA_N: 4096 C: 10.0 gamma:1e-08 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 4096 C: 10.0 gamma:1e-07 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 4096 C: 10.0 gamma:1e-06 accuracy: 0.679 Recall: 0.622,0.736
# Validation PCA_N: 4096 C: 10.0 gamma:1e-05 accuracy: 0.682 Recall: 0.648,0.716
# Validation PCA_N: 4096 C: 10.0 gamma:0.0001 accuracy: 0.737 Recall: 0.758,0.716
# Validation PCA_N: 4096 C: 10.0 gamma:0.001 accuracy: 0.769 Recall: 0.772,0.766
# Validation PCA_N: 4096 C: 10.0 gamma:0.01 accuracy: 0.768 Recall: 0.782,0.754
# Validation PCA_N: 4096 C: 10.0 gamma:0.1 accuracy: 0.751 Recall: 0.724,0.778
# Validation PCA_N: 4096 C: 10.0 gamma:1.0 accuracy: 0.503 Recall: 0.01,0.996
# Validation PCA_N: 4096 C: 10.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0
# Validation PCA_N: 4096 C: 100.0 gamma:1e-08 accuracy: 0.5 Recall: 0.0,1.0
# Validation PCA_N: 4096 C: 100.0 gamma:1e-07 accuracy: 0.679 Recall: 0.622,0.736
# Validation PCA_N: 4096 C: 100.0 gamma:1e-06 accuracy: 0.682 Recall: 0.648,0.716
# Validation PCA_N: 4096 C: 100.0 gamma:1e-05 accuracy: 0.737 Recall: 0.754,0.72
# Validation PCA_N: 4096 C: 100.0 gamma:0.0001 accuracy: 0.768 Recall: 0.774,0.762
# Validation PCA_N: 4096 C: 100.0 gamma:0.001 accuracy: 0.755 Recall: 0.78,0.73
# Validation PCA_N: 4096 C: 100.0 gamma:0.01 accuracy: 0.748 Recall: 0.76,0.736
# Validation PCA_N: 4096 C: 100.0 gamma:0.1 accuracy: 0.751 Recall: 0.724,0.778
# Validation PCA_N: 4096 C: 100.0 gamma:1.0 accuracy: 0.503 Recall: 0.01,0.996
# Validation PCA_N: 4096 C: 100.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0
# Validation PCA_N: 4096 C: 1000.0 gamma:1e-08 accuracy: 0.678 Recall: 0.62,0.736
# Validation PCA_N: 4096 C: 1000.0 gamma:1e-07 accuracy: 0.682 Recall: 0.648,0.716
# Validation PCA_N: 4096 C: 1000.0 gamma:1e-06 accuracy: 0.736 Recall: 0.75,0.722
# Validation PCA_N: 4096 C: 1000.0 gamma:1e-05 accuracy: 0.765 Recall: 0.774,0.756
# Validation PCA_N: 4096 C: 1000.0 gamma:0.0001 accuracy: 0.759 Recall: 0.78,0.738
# Validation PCA_N: 4096 C: 1000.0 gamma:0.001 accuracy: 0.72 Recall: 0.738,0.702
# Validation PCA_N: 4096 C: 1000.0 gamma:0.01 accuracy: 0.746 Recall: 0.758,0.734
# Validation PCA_N: 4096 C: 1000.0 gamma:0.1 accuracy: 0.751 Recall: 0.724,0.778
# Validation PCA_N: 4096 C: 1000.0 gamma:1.0 accuracy: 0.503 Recall: 0.01,0.996
# Validation PCA_N: 4096 C: 1000.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0
# Validation PCA_N: 4096 C: 10000.0 gamma:1e-08 accuracy: 0.682 Recall: 0.648,0.716
# Validation PCA_N: 4096 C: 10000.0 gamma:1e-07 accuracy: 0.734 Recall: 0.752,0.716
# Validation PCA_N: 4096 C: 10000.0 gamma:1e-06 accuracy: 0.764 Recall: 0.774,0.754
# Validation PCA_N: 4096 C: 10000.0 gamma:1e-05 accuracy: 0.759 Recall: 0.778,0.74
# Validation PCA_N: 4096 C: 10000.0 gamma:0.0001 accuracy: 0.717 Recall: 0.728,0.706
# Validation PCA_N: 4096 C: 10000.0 gamma:0.001 accuracy: 0.71 Recall: 0.724,0.696
# Validation PCA_N: 4096 C: 10000.0 gamma:0.01 accuracy: 0.746 Recall: 0.758,0.734
# Validation PCA_N: 4096 C: 10000.0 gamma:0.1 accuracy: 0.751 Recall: 0.724,0.778
# Validation PCA_N: 4096 C: 10000.0 gamma:1.0 accuracy: 0.503 Recall: 0.01,0.996
# Validation PCA_N: 4096 C: 10000.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0
# Validation PCA_N: 4096 C: 100000.0 gamma:1e-08 accuracy: 0.737 Recall: 0.746,0.728
# Validation PCA_N: 4096 C: 100000.0 gamma:1e-07 accuracy: 0.762 Recall: 0.776,0.748
# Validation PCA_N: 4096 C: 100000.0 gamma:1e-06 accuracy: 0.756 Recall: 0.78,0.732
# Validation PCA_N: 4096 C: 100000.0 gamma:1e-05 accuracy: 0.727 Recall: 0.738,0.716
# Validation PCA_N: 4096 C: 100000.0 gamma:0.0001 accuracy: 0.694 Recall: 0.704,0.684
# Validation PCA_N: 4096 C: 100000.0 gamma:0.001 accuracy: 0.71 Recall: 0.724,0.696
# Validation PCA_N: 4096 C: 100000.0 gamma:0.01 accuracy: 0.746 Recall: 0.758,0.734
# Validation PCA_N: 4096 C: 100000.0 gamma:0.1 accuracy: 0.751 Recall: 0.724,0.778
# Validation PCA_N: 4096 C: 100000.0 gamma:1.0 accuracy: 0.503 Recall: 0.01,0.996
# Validation PCA_N: 4096 C: 100000.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0
# Validation PCA_N: 4096 C: 1000000.0 gamma:1e-08 accuracy: 0.759 Recall: 0.764,0.754
# Validation PCA_N: 4096 C: 1000000.0 gamma:1e-07 accuracy: 0.764 Recall: 0.784,0.744
# Validation PCA_N: 4096 C: 1000000.0 gamma:1e-06 accuracy: 0.712 Recall: 0.734,0.69
# Validation PCA_N: 4096 C: 1000000.0 gamma:1e-05 accuracy: 0.699 Recall: 0.704,0.694
# Validation PCA_N: 4096 C: 1000000.0 gamma:0.0001 accuracy: 0.691 Recall: 0.696,0.686
# Validation PCA_N: 4096 C: 1000000.0 gamma:0.001 accuracy: 0.71 Recall: 0.724,0.696
# Validation PCA_N: 4096 C: 1000000.0 gamma:0.01 accuracy: 0.746 Recall: 0.758,0.734
# Validation PCA_N: 4096 C: 1000000.0 gamma:0.1 accuracy: 0.751 Recall: 0.724,0.778
# Validation PCA_N: 4096 C: 1000000.0 gamma:1.0 accuracy: 0.503 Recall: 0.01,0.996
# Validation PCA_N: 4096 C: 1000000.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0
# Validation PCA_N: 4096 C: 10000000.0 gamma:1e-08 accuracy: 0.751 Recall: 0.764,0.738
# Validation PCA_N: 4096 C: 10000000.0 gamma:1e-07 accuracy: 0.768 Recall: 0.782,0.754
# Validation PCA_N: 4096 C: 10000000.0 gamma:1e-06 accuracy: 0.698 Recall: 0.696,0.7
# Validation PCA_N: 4096 C: 10000000.0 gamma:1e-05 accuracy: 0.683 Recall: 0.7,0.666
# Validation PCA_N: 4096 C: 10000000.0 gamma:0.0001 accuracy: 0.691 Recall: 0.696,0.686
# Validation PCA_N: 4096 C: 10000000.0 gamma:0.001 accuracy: 0.71 Recall: 0.724,0.696
# Validation PCA_N: 4096 C: 10000000.0 gamma:0.01 accuracy: 0.746 Recall: 0.758,0.734
# Validation PCA_N: 4096 C: 10000000.0 gamma:0.1 accuracy: 0.751 Recall: 0.724,0.778
# Validation PCA_N: 4096 C: 10000000.0 gamma:1.0 accuracy: 0.503 Recall: 0.01,0.996
# Validation PCA_N: 4096 C: 10000000.0 gamma:10.0 accuracy: 0.501 Recall: 0.002,1.0

# %%
# test
pca_n = 3072
C = 10.0
gamma = 0.01
pca = PCA(n_components=pca_n)
X_tr_pca = pca.fit_transform(X_tr)
X_te_pca = pca.transform(X_te)
svc = svm_train(X_tr_pca, y_tr, C, gamma)
y_pt = svm_predict(svc, X_te_pca)
print ("Test accuracy: {}".format(np.mean(y_pt==y_te)))
recallT = 0.0
recallF = 0.0
for i in range(len(y_te)):
    if (y_pt[i]==y_te[i] and y_pt[i]>0):
        print("the %d accuracy is %s"%(i,y_pt[i]))
        recallT += 1
    if (y_pt[i]==y_te[i] and y_pt[i]<0):
        print("the %d accuracy is %s"%(i,y_pt[i]))
        recallF += 1
print ('Recall: ',recallT/(y_te>0).sum(),recallF/(y_te<=0).sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-75fc20e719c8> in <module>()
#       3 C = 10.0
#       4 gamma = 0.01
# ----> 5 pca = PCA(n_components=pca_n)
#       6 X_tr_pca = pca.fit_transform(X_tr)
#       7 X_te_pca = pca.transform(X_te)
#
# NameError: name 'PCA' is not defined

# %%
import tensorflow as tf
import sys

# 先实例化一个Saver()类
saver = tf.train.Saver()
init = (tf.global_variables_initializer(), tf.local_variables_initializer())

with tf.Session() as sess:
    sess.run(init) 
    # 存储训练好的variables
    save_path = saver.save(sess, "E:/python-workspace/model.ckpt")
    print ("Model saved in file: %s" % save_path)
# Out:
# Model saved in file: E:/python-workspace/model.ckpt

# %%
import tensorflow as tf

pca_n = 3072
C = 10.0
gamma = 0.01

with tf.Session() as sess:
    sess = tf.Session()
    saver = tf.train.Saver()
    saver.restore(sess, "E:/python-workspace/model.ckpt.meta")
    print("Model restored.")
# Out:
# E:\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-bbadef33ef9a> in <module>()
#       7 with tf.Session() as sess:
#       8     sess = tf.Session()
# ----> 9     saver = tf.train.Saver()
#      10     saver.restore(sess, "E:/python-workspace/model.ckpt.meta")
#      11     print("Model restored.")
#
# E:\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py in __init__(self, var_list, reshape, sharded, max_to_keep, keep_checkpoint_every_n_hours, name, restore_sequentially, saver_def, builder, defer_build, allow_empty, write_version, pad_step_number, save_relative_paths, filename)
#    1309           time.time() + self._keep_checkpoint_every_n_hours * 3600)
#    1310     elif not defer_build:
# -> 1311       self.build()
#    1312     if self.saver_def:
#    1313       self._check_saver_def()
#
# E:\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py in build(self)
#    1318     if context.executing_eagerly():
#    1319       raise RuntimeError("Use save/restore instead of build in eager mode.")
# -> 1320     self._build(self._filename, build_save=True, build_restore=True)
#    1321
#    1322   def _build_eager(self, checkpoint_path, build_save, build_restore):
#
# E:\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py in _build(self, checkpoint_path, build_save, build_restore)
#    1343           return
#    1344         else:
# -> 1345           raise ValueError("No variables to save")
#    1346       self._is_empty = False
#    1347
#
# ValueError: No variables to save
